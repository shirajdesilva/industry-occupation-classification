# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('anzsco 2022 structure 062023.xlsx', sheet_name='Table 6', skiprows=5)    
df.head()

# %%
df.shape
# Out:
# (1434, 2)

# %%
# export to parquet
df['Code'] = df['Code'].astype(str)
df.to_parquet('ANZSCO.parquet', index=False)
